# %% [markdown]
# Please fill this part
#
#
# *   Full Name: Walid AlDari
# *   Student Number: 218 375 162
#
# Change file name to yourlast name followed by studentID in the following format and then submit LASTNAME_STUDENTID.ipynb.

# %% [markdown]
# Install profiling
# https://github.com/ydataai/ydata-profiling

# %%
# !pip install ydata-profiling
# !pip install --upgrade typing-extensions
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 9.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=728cb974abd12641ae97a48061f71efad29295b8c72a8e89772e2516d1676b6c
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %% [markdown]
# To initiate a session restart, go to Runtime > Restart Session. Occasionally, the impact of installed libraries may not be visible until a restart is performed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %% [markdown]
# ## Data Transfer: Moving Data from Google Drive to the Current Directory ( 5 pt)
# In this section, we will transfer data from Google Drive to the current working directory and Unzip it. Let's assume that the data is located in "/content/drive/MyDrive/HW2/HW2_Data.zip".

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
################################################################################
## TODO: Use Linux command to transfer and unzip data
################################################################################
# zip file location should be :  "/content/drive/MyDrive/HW2/HW2_Data.zip"
# destination directory for unzipping should be  =>  "/content/"


# !unzip 'drive/MyDrive/HW2/HW2_Data.zip'
# Out:
# Archive:  drive/MyDrive/HW2/HW2_Data.zip
#   inflating: Dataset_Description.pdf
#   inflating: Heart_Disease_Dataset.csv

# %% [markdown]
# ## Load Data ( 5 pt)
# load data in pandas dataframe

# %%
################################################################################
## TODO: load and display dataframe
################################################################################

FILE_PATH="Heart_Disease_Dataset.csv"

dataF = pd.read_csv(FILE_PATH)
dataF
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %% [markdown]
# ## Explore data by ProfileReport ( 5 pt)
# https://github.com/ydataai/ydata-profiling
#
# Just simply run ProfileReport in 2 lines

# %%
################################################################################
## TODO: Use profiler in 2 line and explore the data
################################################################################

profile = ProfileReport(dataF, title="Profiling Report")
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-07-09 13:21:18.956273&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## Explore data by Panda ( 5pt )

# %%
#############################################################################
## TODO: Find the shape of the dataset.
#############################################################################

print("shape of dataset is: ", dataF.shape)

print("--------------------------------------------------")
#############################################################################
## TODO: Check if there are missing entries in the dataset columnwise.
#############################################################################

print(dataF.isna().sum())

print("--------------------------------------------------")
#############################################################################
## TODO: Check number of positive and negative cases
#############################################################################

print(dataF["target"].value_counts())


#############################################################################
## TODO: plot  age distribution and gender distribution for both normal
## and heart disease patients. (2*2 plots)
#############################################################################

print("--------------------- Plots --------------------------")

normalPatients = dataF[dataF["target"] == 0]
sickPatients = dataF[dataF["target"] == 1]

fig, axs = plt.subplots(2,2, figsize=(10, 10))

sns.histplot(data=normalPatients, x="age", kde=True, ax=axs[0][0])
axs[0][0].set_title("Age Distribution of Normal Patients")
axs[0][0].set_xlabel("age")
axs[0][0].set_ylabel("cont")

sns.histplot(data=sickPatients, x="age", kde=True, ax=axs[1][0])
axs[1][0].set_title("Age Distribution of heart disease Patients")
axs[1][0].set_xlabel("age")
axs[1][0].set_ylabel("cont")

normalPatients["sex"].value_counts(ascending=True).plot(kind="bar", ax=axs[0][1])
# normalPatients["sex"].hist(grid=False, ax=axs[0][1], bins=3)
# normalPatients["age"].plot(kind="kde", color="black", ax=axs[0][0])
axs[0][1].set_title("Gender Distribution of Normal Patients")
axs[0][1].set_xlabel("sex")
axs[0][1].set_ylabel("cont")

sickPatients["sex"].value_counts(ascending=True).plot(kind="bar", ax=axs[1][1])
# sickPatients["sex"].hist(grid=False, ax=axs[1][1], bins=3)
# normalPatients["age"].plot(kind="kde", color="black", ax=axs[0][0])
axs[1][1].set_title("Gender Distribution of heart disease Patients")
axs[1][1].set_xlabel("sex")
axs[1][1].set_ylabel("cont")

plt.show()
# Out:
# shape of dataset is:  (1190, 12)
# --------------------------------------------------
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64
# --------------------------------------------------
# target
# 1    629
# 0    561
# Name: count, dtype: int64
# --------------------- Plots --------------------------

# %% [markdown]
# ## Split Data ( 2 pt )
# Before any action you should do this step to prevent from leak of data and using test data in your tunning pipeline

# %%
from sklearn.model_selection import train_test_split
#############################################################################
## TODO: split dataframe into 4 dataframe X_train, X_test, y_train, y_test
## test(30%) train(70%)
# Assuming df is your DataFrame and 'target_column' is your target variable
# Split the data into training and testing sets with 0.7 to 0.3 ratio
#############################################################################

target_column = "target"

X_train, X_test, y_train, y_test = train_test_split(dataF.loc[:, dataF.columns != target_column], dataF[target_column], test_size=0.3, train_size=0.7, shuffle=True, random_state = 1)

X_train
# X_test.head()
# y_train.head()
# y_test.head()
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 264    59    1                4           130          126
# 1032   47    1                3           108          243
# 56     31    1                4           120          270
# 1094   50    1                4           144          200
# 1141   43    1                4           115          303
# ...   ...  ...              ...           ...          ...
# 715    64    0                3           140          313
# 905    48    0                3           130          275
# 1096   62    0                4           150          244
# 235    54    0                2           140          309
# 1061   64    1                4           145          212
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 264                     0            0             125                0
# 1032                    0            0             152                0
# ...

# %% [markdown]
# ## Feature Engineering:( 8 pt)
# Sometimes the collected data are raw; they are either incompatible with your model or hinders its performance. That’s when feature engineering comes to rescue. It encompasses preprocessing techniques to compile a dataset by extracting features from raw data.

# %%
from sklearn.preprocessing import StandardScaler
#############################################################################
## TODO: Normalize numerical features
## Note that just numerical fetures should be normalized.
## Type of features is determined in dataset description file.
# Create a StandardScaler instance
# Fit to numerical columns of train and transform test and train based on this
## Warning:
## You can't fit your Scaler on whole data. Fit should be just on Train data.
# Print the first few rows to check the result
#############################################################################

scaler = StandardScaler()

numerical_columns = ['age', 'resting bp s', 'cholesterol', 'max heart rate', 'oldpeak']

splicedX_train = X_train.loc[:, numerical_columns]
splicedX_test = X_test.loc[:, numerical_columns]

scaler.fit(splicedX_train)

scaler.transform(splicedX_train)
scaler.transform(splicedX_test)

X_train.loc[:, ['age', 'resting bp s', 'cholesterol', 'max heart rate', 'oldpeak']] = scaler.transform(splicedX_train)
X_test.loc[:, ['age', 'resting bp s', 'cholesterol', 'max heart rate', 'oldpeak']] = scaler.transform(splicedX_test)

print(X_train.head())
#############################################################################
## TODO: just comment name of 2 other scaler form sklearn and write one paragraph for each:
## Your Comment:


# MinMaxScaler

# A rescale technique which results in the feature values following the range [0,1]. It's used sometimes instead of the zero mean, unit variance scaling, and it
# doesn't reduce the effect of outliers, instead they take the max values 0 and 1 after the scaling process.
# This technique follows this transformation (taken from the sklearn docs):
# X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
# X_scaled = X_std * (max - min) + min
# The code above is taken directly from the sklearn docs on MinMaxScaler


# RobustScaler

# Unlike the MinMaxScaler, this RobustScaler is robust to outliers through the use of statistical scale features.
# It focuses on median removal and then scales the data according to the Interquartile Range, the interquartile range is between the 25th quantile
# and the 75th quantile.
# The use of the interquartile range and the median removal can help in countering the sensitivity to outliers.


# Sources used for research:
# https://www.kaggle.com/discussions/general/138076
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html

##################################################################################
# Out:
#            age  sex  chest pain type  resting bp s  cholesterol  \
# 264   0.580359    1                4     -0.120048    -0.824736
# 1032 -0.713701    1                3     -1.326191     0.317636
# 56   -2.439114    1                4     -0.668295     0.581260
# 1094 -0.390186    1                4      0.647497    -0.102210
# 1141 -1.145054    1                4     -0.942418     0.903468
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 264                     0            0       -0.563734                0
# 1032                    0            0        0.500025                0
# 56                      0            0        0.539423                1
# 1094                    0            2       -0.524336                1
# 1141                    0            0        1.642581                0
#
#        oldpeak  ST slope
# 264  -0.851084         2
# 1032 -0.851084         1
# 56    0.517375         2
# 1094 -0.030009         2
# ...

# %% [markdown]
# ### plot correlations ( 2 pt)

# %%
from pandas import concat
#############################################################################
## TODO: Make a temp dataframe with X_train and y_train.
## plot correlation between all features
#############################################################################

tempDF = concat([X_train, y_train], axis=1)

corrTable = tempDF.corr(method='pearson')

plt.figure(figsize=(12,10))
sns.heatmap(corrTable, annot=True)
plt.show()

# %% [markdown]
# ## Define a classification report function ( 3 pt)

# %%
#############################################################################
## TODO: Complete this function by considering function description
## Note: write every thing from scatch with python or numpy operators
#############################################################################

def classification_report(y_true, y_pred):


    """
    Calculate classification metrics based on true and predicted labels.

    Parameters:
    - y_true: Array of true labels (0 or 1).
    - y_pred: Array of predicted labels (0 or 1).

    Returns:
    - Accuracy: Ratio of correct predictions to total samples.
    - Precision: Accuracy of positive predictions among all predicted positives.
    - Recall: Ability to capture actual positives among all actual positives.
    - F1 Score: Harmonic mean of precision and recall, balancing both metrics.
    - FNR: Proportion of actual positives incorrectly predicted as negatives.
    """

################### Complete this part###############################

    correct_count = 0
    true_pos = 0
    false_pos = 0
    false_neg = 0

    for i in range(len(y_true)):
      if y_true[i] == y_pred[i]:
        correct_count += 1
      if np.logical_and(y_true[i], y_pred[i]):
        true_pos += 1
      if y_pred[i] == 1 and y_true[i] == 0:
        false_pos += 1
      if y_pred[i] == 0 and y_true[i] == 1:
        false_neg += 1

    Accuracy = correct_count / len(y_true)
    Precision = true_pos/(true_pos+false_pos)
    Recall = true_pos/(true_pos+false_neg)
    F1score = (2*Precision*Recall) / (Precision + Recall)
    FNR = false_neg/(false_neg+true_pos)


####################################################################


    result = {
        'Accuracy:' : Accuracy,
        'Precision:' : Precision,
        'Recall:' : Recall,
        'F1score:': F1score,
        'FNR:': FNR

    }

    return result


# Test function





# Test Case 1: Perfect predictions
y_true_1 = [1, 0, 1, 0]
y_pred_1 = [1, 0, 1, 0]
result_1 = classification_report(y_true_1, y_pred_1)
print(result_1)


# Test Case 2: Imperfect predictions
y_true_2 = [1, 0, 1, 0]
y_pred_2 = [0, 1, 1, 1]

result_2 = classification_report(y_true_2, y_pred_2)
print(result_2)
# Out:
# {'Accuracy:': 1.0, 'Precision:': 1.0, 'Recall:': 1.0, 'F1score:': 1.0, 'FNR:': 0.0}
# {'Accuracy:': 0.25, 'Precision:': 0.3333333333333333, 'Recall:': 0.5, 'F1score:': 0.4, 'FNR:': 0.5}

# %% [markdown]
# ## Model Traning

# %% [markdown]
# ### Covert data to numpy ( 2 pt)

# %%
#############################################################################
## TODO: convert X_train, X_test, y_train, y_test to numpy array
#############################################################################

X_train = X_train.to_numpy()
X_test = X_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %% [markdown]
# ### Train Logistic Regression ( 5pt)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
#############################################################################
## TODO: Train a Logistic Regression Model and test your model.
## give a test report from test result by above classification_report function
## Plot the confusion matrix using seaborn
#############################################################################

logModel = LogisticRegression(random_state = 1).fit(X_train, y_train)

X_Model_test = logModel.predict(X_test)
test_result = classification_report(X_Model_test, y_test)
print(test_result)

CMatrix = confusion_matrix(y_test, X_Model_test)
# print(CMatrix)

axe = plt.axes()

sns.heatmap(CMatrix, annot=True, xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'], fmt="d", square=True, ax=axe)
axe.set_title("Confusion Matrix - Logistic Regression")
# Out:
# {'Accuracy:': 0.8487394957983193, 'Precision:': 0.8548387096774194, 'Recall:': 0.8548387096774194, 'F1score:': 0.8548387096774194, 'FNR:': 0.14516129032258066}
# Text(0.5, 1.0, 'Confusion Matrix - Logistic Regression')

# %% [markdown]
# ### Train KNN ( 5pt)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

#############################################################################
## TODO: Train a KNN Model and test your model.
## give a test report from test result by above classification_report function
## plot confusion matrix
#############################################################################

KNNModel = KNeighborsClassifier().fit(X_train, y_train)

X_Model_test = KNNModel.predict(X_test)

test_result = classification_report(X_Model_test, y_test)
print(test_result)

CMatrix = confusion_matrix(y_test, X_Model_test)
# print(CMatrix)

axe = plt.axes()


sns.heatmap(CMatrix, annot=True, xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'], fmt="d", square=True, ax=axe)

axe.set_title("Confusion Matrix - K-Nearest Neighbors")
# Out:
# {'Accuracy:': 0.8487394957983193, 'Precision:': 0.8494623655913979, 'Recall:': 0.8586956521739131, 'F1score:': 0.854054054054054, 'FNR:': 0.14130434782608695}
# Text(0.5, 1.0, 'Confusion Matrix - K-Nearest Neighbors')

# %% [markdown]
# ### Train a safer model ( 3pt)
#
# To make sure our model doesn't make dangerous mistakes, like saying a high-risk patient is healthy, we can use the class_weight option in LogisticRegression(). If the model wrongly thinks a healthy person is high-risk, it's not as big of a problem and doctors will check it!

# %%
#############################################################################
## TODO: create a safer model with class_weight use your owen weight result is not important
## plot confusion matrix
#############################################################################
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve

weights = {
    0: 0.3,
    1: 0.7
}

saferLogModel = LogisticRegression(random_state = 1, class_weight=weights).fit(X_train, y_train)

X_Model_test = saferLogModel.predict(X_test)
test_result = classification_report(X_Model_test, y_test)
print(test_result)

CMatrix = confusion_matrix(y_test, X_Model_test)
# print(CMatrix)
axe = plt.axes()

sns.heatmap(CMatrix, annot=True, xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'], fmt="d", square=True, ax=axe)

axe.set_title("Confusion Matrix - Safe Logistic Regression")
# Out:
# {'Accuracy:': 0.8263305322128851, 'Precision:': 0.9301075268817204, 'Recall:': 0.7792792792792793, 'F1score:': 0.8480392156862746, 'FNR:': 0.22072072072072071}
# Text(0.5, 1.0, 'Confusion Matrix - Safe Logistic Regression')

# %% [markdown]
# ### Cross Validation Score ( 5pt)

# %%
from sklearn.model_selection import cross_validate
#############################################################################
## TODO: research  about "K-Fold cross validation"
## cross validate your KNN model to evaluate your model better
## use accuracy and recall to report cross validation results
#############################################################################
k = 5
validationResults = cross_validate(KNNModel, X_train, y_train, scoring=['accuracy', 'recall'])

# print(validationResults)

# highestAvg = 0
# indexOfHighest = 0
# for i in range(len(validationResults['test_accuracy'])):
#   avg = (validationResults['test_accuracy'][i] + validationResults['test_recall'][i])/2
#   if avg > highestAvg:
#     highestAvg = avg
#     indexOfHighest = i

# print("KNN Acc: ", validationResults['test_accuracy'][indexOfHighest])
# print("KNN Recall: ", validationResults['test_recall'][indexOfHighest])


# I was informed by the TA that I should take the avg of values present in each of test_accuracy and test_recall. However, if that's not the case, the code snippet
#   displays the highest value possible by a specific fold.
print("KNN Acc: ", validationResults['test_accuracy'].mean())
print("KNN Recall: ", validationResults['test_recall'].mean())
# Out:
# KNN Acc:  0.8066806146742659
# KNN Recall:  0.8171092951991827

# %% [markdown]
# ### Hyperparameter Tuning Using GridSearchCV ( 5pt)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
#############################################################################
## TODO: Explore GridSearchCV functionality to identify the best parameters
## (n_neighbors, weights, p) for your KNN model.
#############################################################################
params = {
    'n_neighbors' : np.arange(1,25),
    'weights': ['uniform', 'distance'],
    'p': [1,2,3]
}

gridSearch = GridSearchCV(KNNModel, params, scoring=['accuracy', 'recall'], refit='accuracy')

# %%
#############################################################################
## TODO: Retrieve the best model and its parameters
#############################################################################
results = gridSearch.fit(X_train, y_train)
print("Best Parameters: ", results.best_params_)
print("Best Accuracy: ", results.best_score_)

BestKNNModel = KNeighborsClassifier(**results.best_params_)
BestKNNModel.fit(X_train, y_train)
# Out:
# Best Parameters:  {'n_neighbors': 12, 'p': 1, 'weights': 'distance'}
# Best Accuracy:  0.8943438424356108
# KNeighborsClassifier(n_neighbors=12, p=1, weights='distance')

# %% [markdown]
# ### Cross Validation Score on Result of Gride Search ( 2pt)

# %%
#############################################################################
## TODO: Do again "K-Fold cross validation" on best KNN model of the Gride Search
#############################################################################


validationResults = cross_validate(BestKNNModel, X_train, y_train, scoring=['accuracy', 'recall'])

# print(validationResults)

# highestAvg = 0
# indexOfHighest = 0
# for i in range(len(validationResults['test_accuracy'])):
#   avg = (validationResults['test_accuracy'][i] + validationResults['test_recall'][i])/2
#   if avg > highestAvg:
#     highestAvg = avg
#     indexOfHighest = i

# print("KNN Acc: ", validationResults['test_accuracy'][indexOfHighest])
# print("KNN Recall: ", validationResults['test_recall'][indexOfHighest])


print("KNN Acc: ", validationResults['test_accuracy'].mean())
print("KNN Recall: ", validationResults['test_recall'].mean())
# Out:
# KNN Acc:  0.8943438424356108
# KNN Recall:  0.9074310520939735

# %% [markdown]
# ### Is the aforementioned KNN model (Best KNN) fair? ( 3 pt)
# Evaluate that model perform equally on men and women or not.

# %%
#############################################################################
## TODO: split your test data on two split of women and men and give
## classification_report on them.
#############################################################################

ZeroX_test = X_test[X_test[:,1] == 0]
Zeroy_test = y_test[X_test[:,1] == 0]

OneX_test = X_test[X_test[:,1] == 1]
Oney_test = y_test[X_test[:,1] == 1]


ZeroClassificationReport = classification_report(Zeroy_test, BestKNNModel.predict(ZeroX_test))
OneClassificationReport = classification_report(Oney_test, BestKNNModel.predict(OneX_test))

print("Performance of best KNN model for  sex_group of '0.0':")
print(ZeroClassificationReport)
print("Performance of best KNN model for  sex_group of '1.0':")
print(OneClassificationReport)


#############################################################################
## TODO: write a comment and explain the result of this section in one paragraph.
## Why FNR in this dataset is important? And probably why this gap between men
## and women FNR happens
# Your Comment:
# Let's assume that 1.0 is male and 0.0 is female, given that most research on heart disease is based off men's symptoms mostly.
# The below statistics state that the accuracy and precision at identifying targets of either gender doesn't vary much, however the recall gives us another story.
# The recall for the male group is 0.97 which is significantly higher than the recall of 0.89 for women, which means that the likelihood for a man who tests positive
# to be classified as positive by the model is much higher than the women's. Therefore, there is a higher chance for a woman who tests positive to not be classified as positive
# by the model, which reveals a major flaw in the model.
#
#In the context of FNR, the FNR for women is much higher meaning a woman who actually tests positive is categorized by the model as negative. Therefore true positives are
# categorized as true negatives.
#
#############################################################################
# Out:
# Performance of best KNN model for  sex_group of '0.0':
# {'Accuracy:': 0.9504950495049505, 'Precision:': 0.8571428571428571, 'Recall:': 0.96, 'F1score:': 0.9056603773584904, 'FNR:': 0.04}
# Performance of best KNN model for  sex_group of '1.0':
# {'Accuracy:': 0.921875, 'Precision:': 0.9607843137254902, 'Recall:': 0.9130434782608695, 'F1score:': 0.9363057324840764, 'FNR:': 0.08695652173913043}

# %% [markdown]
# ### Ensemble Leanrning ( 10 pt)

# %% [markdown]
# First read the first part of this blog
# https://rasbt.github.io/mlxtend/user_guide/classifier/StackingCVClassifier/

# %%
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from mlxtend.classifier import StackingCVClassifier
from sklearn import metrics


#############################################################################
## TO-DO: Implement a Stacking Classifier Ensemble for Model Selection
## 1. Utilize a Logistic Regression, the best K-Neighbors Classifier,
##    Support Vector Machine (SVM), Soft-margin SVM, Decision Tree,
##    Random Forest, and Naive Bayes as base classifiers.
## 2. Designate a Logistic Regression as the Meta-Classifier.
## 3. Utilize 3-fold cross-validation for model evaluation.
## 4. Assess models' performance on the test set.
#############################################################################



clf1 = KNeighborsClassifier(**results.best_params_)
clf2 = LogisticRegression()
clf3 = SVC()
clf4 = SVC(C=0.1)
clf5 = DecisionTreeClassifier()
clf6 = GaussianNB()

lr = LogisticRegression()

sclf = StackingCVClassifier(classifiers=[clf1, clf2, clf3, clf4, clf5, clf6],
                            meta_classifier=lr)

print('Evaluation on the test set :\n')

for clf, label in zip([clf1, clf2, clf3, clf4, clf5, clf6, sclf],
                      ['KNN', 'LR', 'SVM', 'SoftSVM', 'DecisionTree', 'NaiveBayes', 'Ensemble Classifier']):

    scores = model_selection.cross_val_score(clf, X_test, y_test, scoring='accuracy', cv=3)
    print("accuracy: %0.2f on %s"
          % (scores.mean(), label))
# Out:
# Evaluation on the test set :
#
# accuracy: 0.87 on KNN
# accuracy: 0.83 on LR
# accuracy: 0.86 on SVM
# accuracy: 0.82 on SoftSVM
# accuracy: 0.82 on DecisionTree
# accuracy: 0.85 on NaiveBayes
# accuracy: 0.86 on Ensemble Classifier

# %% [markdown]
# ### ROC ( 10 pt)
# read about AUC ROC form this link:
# https://medium.com/greyatom/lets-learn-about-auc-roc-curve-4a94b4d88152
# and plot ROC Curve for ensembel model.

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay

#############################################################################
## TODO: plot roc_curve for Ensemble model you created previously
#############################################################################

sclf.fit(X_train, y_train)
predictions = sclf.predict(X_test)

fpr, tpr, thresholds = metrics.roc_curve(y_test, predictions)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='Heart Disease Estimation')
display.plot()


#############################################################################
## TODO: what this plot can show us that other metrics like Accuracy can't:
## Your Comment:
#
# This plot is plotted through the formula (1-specificity) which is derived by calculating 1-(TN/TN+FP). Because it's 1-specificity, we know that if
# that metric increases, then sensitivity/recall also increases with it.
# Thus this plot showcases more than just the "accuracy" of the model, but it also provides us with insights into the potential sensitivity/recall of the model.
# The gap under the line also tells us more about how well the model can differentiate between 2 items, in our case whether the patient has the heart
# disease or not.
#
#
#
#
#############################################################################
